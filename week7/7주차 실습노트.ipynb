# %% [markdown]
# 과제

# %%
import math
w = 8
h = 5

print(math.sqrt(w**2 + h**2))
print(math.sqrt(8 * 8 + 5 * 5))
# Out:
# 9.433981132056603
# 9.433981132056603

# %%
from datetime import date

'''
now = datetime.now()
date_birth = datetime.strptime("19940505", "%Y%m%d")

dif = now - date_birth
print("{} days, 0:00:00".format(dif.days))
'''
birth = date(1994, 5, 5)
today = date.today()
print(today - birth)
# Out:
# 10028 days, 0:00:00

# %%
import random

for i in range(10):
  print(random.randint(10, 20)) #두번째 파라미터도 범위에 포함된다.
# Out:
# 17
# 13
# 14
# 15
# 12
# 12
# 15
# 12
# 16
# 17

# %%
a, b = map(int, input('숫자 두 개를 입력하세요: ').split())
try:  
  rst = a / b
  print(rst)
except:
  print('division by zero')
# Out:
# 숫자 두 개를 입력하세요: 50 0
# division by zero

# %%
강의노트

# %%
import random

food = ['떡볶이', '피자', '햄버거', '브리또']

def choice(food):
  i = random.randrange(len(food))
  return food[i]

print(choice(food))

def choice(food):
  i = random.randrange(len(food))
  return food[i]
# Out:
# 햄버거

# %%
score = int(input("점수를 입력하세요 : "))
assert score <= 100, "점수는 100 이하여야 합니다."
print(score)
# Out:
# 점수를 입력하세요 : 40
# 40
