# %%
a = 12; b = 34
print(a, b, sep = ', ', end = '!\n')
# Out:
# 12, 34!

# %%
age = int(input('old? '))
print(age)
print(age + 1)
# Out:
# old? 50
# 50
# 51

# %%
value = 1234
value = 'computer'

# %%
print(''' I think cats are so cute.
Because cats have .
So I love ''')
# Out:
#  I think cats are so cute.
# Because cats have .
# So I love

# %%
member = ['a', 'b', 'c', 'd', 'e']
print(member)

for m in member: print(m, "짱")

member = ('a', 'b', 'c', 'd', 'e')

for m in member: print(m, "짱")
# Out:
# ['a', 'b', 'c', 'd', 'e']
# a 짱
# b 짱
# c 짱
# d 짱
# e 짱
# a 짱
# b 짱
# c 짱
# d 짱
# e 짱

# %%
candy = 4000
money = 1000
print(candy / money)

print(candy // money)
# Out:
# 4.0
# 4

# %%
print('I am haein ' * 3)

print('I have ' + str(2) + ' legs')

print(10 + int('12'))
# Out:
# I am haein I am haein I am haein
# I have 2 legs
# 22

# %%
24 * 60 * 60

w = int(input('width: '))
h = int(input('height: '))
print(w * h)

season = ['봄', '여름', '가을', '겨울']
for s in season:
  print(s)
# Out:
# width: 20
# height: 39
# 780
# 봄
# 여름
# 가을
# 겨울

# %%
season = '봄\n여름\n가을\n겨울\n'

print(season)

print('문자 K의 코드값은', ord('K'))
print('코드값 100의 문자는', chr(100))
# Out:
# 봄
# 여름
# 가을
# 겨울
#
# 문자 K의 코드값은 75
# 코드값 100의 문자는 d

# %%
s = int(input('점수를 입력하세요: '))

if s >= 80:
  print('합격')
else:
  print('불합격')
# Out:
# 점수를 입력하세요: 90
# 합격

# %%
c = input('한국의 수도는 어디일까요? ')
if c == '서울':
  print('정답')
  print('축하합니다')
# Out:
# 한국의 수도는 어디일까요? 서울
# 정답
# 축하합니다

# %%
n = int(input('5배수: '))
if n % 5 == 0 and n != 0:
  print('5의 배수입니다')
else:
  print('5의 배수가 아닙니다')
# Out:
# 5배수: 90
# 5의 배수입니다

# %%
seoul = 2500 / 1
mail = 4200 / 1.8

if seoul < mail:
  print('서울 우유를 사자')
else:
  print('매일 우유를 사자')
# Out:
# 매일 우유를 사자
